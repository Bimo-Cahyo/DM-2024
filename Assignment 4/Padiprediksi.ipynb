# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %%
file_path = 'produksiPadi.xlsx'
data = pd.read_excel(file_path)

# %%
# Preprocessing data
data.columns = ['Tahun', 'Produksi']  # Rename columns for consistency
data['Produksi_Lag'] = data['Produksi'].shift(1)  # Create lagging feature
data = data.dropna()  # Remove rows with NaN

# %%
# Define features and target variable
X = data[['Produksi_Lag']]
y = data['Produksi']

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Initialize and train the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on test data
y_pred = model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = mse**0.5
mape = mean_absolute_percentage_error(y_test, y_pred)

# %%
# Output results
print("Model Evaluation Metrics:")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2%}")
# Out:
# Model Evaluation Metrics:
# MSE: 36689087343786.89
# RMSE: 6057151.75
# MAPE: 5.14%

# %%
import pandas as pd

# Assuming the feature name during training was 'Produksi'
input_2023 = pd.DataFrame({'Produksi': [last_production]})
pred_2023 = model.predict(input_2023)

input_2024 = pd.DataFrame({'Produksi': [pred_2023[0]]})
pred_2024 = model.predict(input_2024)

print("Prediction for 2023:", pred_2023[0])
print("Prediction for 2024:", pred_2024[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 5
#       3 # Assuming the feature name during training was 'Produksi'
#       4 input_2023 = pd.DataFrame({'Produksi': [last_production]})
# ----> 5 pred_2023 = model.predict(input_2023)
#       7 input_2024 = pd.DataFrame({'Produksi': [pred_2023[0]]})
#       8 pred_2024 = model.predict(input_2024)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
# ...

# %%
print("\nPredictions:")
print(f"2023: {pred_2023[0]:,.2f} Ton")
print(f"2024: {pred_2024[0]:,.2f} Ton")
# Out:
# Predictions:
# 2023: 55,703,980.48 Ton
# 2024: 57,078,475.55 Ton
